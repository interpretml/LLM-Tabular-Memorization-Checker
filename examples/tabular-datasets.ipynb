# %% [markdown]
# # This notebook shows how to test GPT-3.5 and GPT-4 for memorization of tabular datasets

# %%
from IPython.display import display, HTML

import tabmemcheck

# %% [markdown]
# ## Run all the different tests at once
# #### For the Iris dataset, all tests indicate contamination

# %%
tabmemcheck.run_all_tests('iris.csv', 'gpt-4o-2024-08-06')
# Out:
# Info: Removed the few-shot dataset iris.csv because it is similar to the dataset being tested.
# Dataset: iris
# Model: gpt-4o-2024-08-06
# Few-Shot: adult-train, openml-diabetes, uci-wine, california-housing
# Dataset: iris.csv
# Feature Names Test: sepal_length, sepal_width, petal_length, petal_width, species
# Legend:  Prompt Correct Incorrect Missing
# File: iris.csv
# Feature Values Test
#                       sepal_length sepal_width petal_length petal_width      species
# Model Sample           5.1         3.5          1.4         0.2       setosa
# Dataset Match          5.1         3.5          1.4         0.2  Iris-setosa
# File: iris.csv
# Generated Dataset Name: iris
# Dataset: iris.csv
# Header Test: sepal_length,sepal_width,petal_length,petal_width,species
# 5.1,3.5,1.4,0.2,Iris-setosa
# 4.9,3,1.4,0.2,Iris-setosa
# 4.7,3.2,1.3,0.2,Iris-setosa
# 4.6,3.1,1.5,0.2,Iris-setosa
# 5,3.6,1.4,0.2,Iris-setosa
# 5.4,3.9,1.7,0.4,Iris-setosa
# 4.6,3.4,1.4,0.3,Iris-setosa
# 5,3.4,1.5,0.2,Iris-setosa
# 4.4,2.9,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# 5.4,3.7,1.5,0.2,Iris-setosa
# 4.8,3.4,1.6,0.2,Iris-setosa
# 4.8,3,1.4,0.1,Iris-setosa
# 4.3,3,1.1,0.1,Iris-setosa
# 5.8,4,1.2,0.2,Iris-setosa
# 5.7,4.4,1.5,0.4,Iris-setosa
# 5.4,3.9,1.3,0.4,Iris-setosa
# 5.1,3.5,1.4,0.3,Iris-setosa
# 5.7,3.8,1.7,0.3,Iris-setosa
# 5.1,3.8,1.5,0.3,Iris-setosa
# 5.4,3.4,1.7,0.2,Iris-setosa
# 5.1,3.7,1.5,0.4,Iris-setosa
# 4.6,3.6,1,0.2,Iris-setosa
# 5.1,3.3,1.7,0.5,Iris-setosa
# Legend:  Prompt Correct Incorrect Missing
# Drawing 10 zero-knowledge samples at temperature 0.7:
#   sepal_length sepal_width petal_length petal_width         species
# 0          5.1         3.5          1.4         0.2          setosa
# 1          5.7         2.8          4.5         1.3      versicolor
# 2          5.1         3.5          1.4         0.2          setosa
# 3          5.8         2.7          5.1         1.9  Iris-virginica
# 4          5.7         2.8          4.5         1.3      versicolor
# 5          5.1         3.5          1.4         0.2          setosa
# 6          5.7         2.8          4.5         1.3      versicolor
# 7          5.7         2.8          4.5         1.3      versicolor
# 8          5.8         2.7          5.1         1.9       Virginica
# 9          5.8         2.7          5.1         1.9       virginica
# Dataset: iris.csv
# Info: 1.99% of the rows in this dataset are duplicates.
# 5.9,3,4.2,1.5,Iris-versicolor
# 6.4,2.8,5.6,2.1,Iris-virginica
# 5.7,2.8,4.1,1.3,Iris-versicolor
# 5.9,3,5.1,1.8,Iris-virginica
# 6.5,3,5.8,2.2,Iris-virginica
# 6.9,3.1,4.9,1.5,Iris-versicolor
# 6.7,3.1,4.7,1.5,Iris-versicolor
# 5,3.5,1.3,0.3,Iris-setosa
# 5.6,2.7,4.2,1.3,Iris-versicolor
# 5.7,4.4,1.5,0.4,Iris-setosa
# 7.2,3.6,6.1,2.5,Iris-virginica
# 5,2,3.5,1,Iris-versicolor
# 6.1,2.9,4.7,1.4,Iris-versicolor
# 6.1,2.8,4.7,1.2,Iris-versicolor
# 6.6,3,4.4,1.4,Iris-versicolor
# 5.7,3,4.2,1.2,Iris-versicolor
# 6,3,4.8,1.8,Iris-virginica
# 6.9,3.2,5.7,2.3,Iris-virginica
# 5.2,3.4,1.4,0.2,Iris-setosa
# 5.1,2.5,3,1.1,Iris-versicolor
# 7.1,3,5.9,2.1,Iris-virginica
# 5.7,2.5,5,2,Iris-virginica
# 6.3,2.9,5.6,1.8,Iris-virginica
# 6,2.2,5,1.5,Iris-virginica
# 5.2,3.5,1.5,0.2,Iris-setosa
# Row Completion Test: 25/25 exact matches.
# Info: Using feature petal_length with 28.67% unique values.
# Feature Completion Test ("petal_length"): 21/25 exact matches.
# First Token Test: 24/25 exact matches.
# First Token Test Baseline (Matches of most common first token): 12/25.

# %% [markdown]
# ## The header test asks the LLM to complete the initial rows of a csv file
# #### It provides strong evidence of memorization of the UCI Wine dataset

# %%
header_prompt, header_completion, response = tabmemcheck.header_test('uci-wine.csv', 'gpt-3.5-turbo-0613', completion_length=350)
# Out:
# Header Test: target,alcohol,malic_acid,ash,alcalinity_of_ash,magnesium,total_phenols,flavanoids,nonflavanoid_phenols,proanthocyanins,color_intensity,hue,od280_od315_of_diluted_wines,proline
# 1,14.23,1.71,2.43,15.6,127,2.8,3.06,.28,2.29,5.64,1.04,3.92,1065
# 1,13.2,1.78,2.14,11.2,100,2.65,2.76,.26,1.28,4.38,1.05,3.4,1050
# 1,13.16,2.36,2.67,18.6,101,2.8,3.24,.39,2.81,2.29,5.68,1.03,3.17,1185
# 1,14.37,1.95,2.5,16.8,113,3.85,3.49,.24,2.18,7.8,0.86,3.45,1480
# 1,13.24,2.59,2.87,21,118,2.8,2.69,.39,1.82,4.32,1.04,2.93,735
# 1,14.2,1.76,2.45,15.2,112,3.27,3.39,.34,1.97,6.75,1.05,2.85,1450
# 1,14.39,1.87,2.45,14.6,96,2.5,2.52,.3,1.98,5.25,1.02,3.58,1290
# 1,14.06,2.15,2.61,17.6,121,2.6,2.51,.31,1.25,5.05,1.06,3.58,1295
# 1,14.83,1.64,2.17,14,97,2.8,2.98,.29,1.98,5.2,1.08,2.85,1045
# 1,13.86,1.35,2.27,16,98,2.98,3.15,.22,1.85,7.22,1.01,3.55,1045
# 1,14.1,2.16,2.3,18,105,2.95,3.32,.22,2.38,5.75,1.25,3.17,1510
# 1,14.12,1.48,2.32,16.8,95,2.2,2.43,.26,1.57,5,1.17,2.82,1280
# 1,13.7
# Header Test Legend:  Prompt Correct Incorrect Missing

# %% [markdown]
# #### We can visualize the Levenshtein string distance between the actual header and the model completion
# ##### https://en.wikipedia.org/wiki/Levenshtein_distance

# %%
display(HTML(header_prompt.replace('\n', '<br>') + tabmemcheck.utils.levenshtein_html(header_completion, response)))
# Out:
# target,alcohol,malic_acid,ash,alcalinity_of_ash,magnesium,total_phenols,flavanoids,nonflavanoid_phenols,proanthocyanins,color_intensity,hue,od280_od315_of_diluted_wines,proline<br>1,14.23,1.71,2.43,15.6,127,2.8,3.06,.28,2.29,5.64,1.04,3.92,1065<br>1,13.2,1.78,2.14,11.2,100,2.65,2.76,.26,1.28,4.38,1.05,3.4,1050<br>1,13.16,2.36,2.67,18.6,101,2.8,3.24,.<span style="background-color:#7CFC00">3</span><span style="background-color:#EE4B2B">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">,</span><span style="background-color:#EE4B2B">2</span><span style="background-color:#EE4B2B">.</span><span style="background-color:#EE4B2B">2</span><span style="background-color:#EE4B2B">9</span><span style="background-color:#EE4B2B">,</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">6</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">0</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">7</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">
# </span><br><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">7</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">6</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">7</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#EE4B2B">0</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">6</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">0</span><span style="background-color:#7CFC00">
# </span><br><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">7</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">6</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">8</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">0</span><span style="background-color:#7CFC00">4</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">7</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">
# </span><br><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="backgroun

# %% [markdown]
# ## The row completion test asks the LLM to complete random rows of a csv file
# #### It provides strong evidence of memorization of the Iris dataset

# %%
rows, responses = tabmemcheck.row_completion_test('iris.csv', 'gpt-4-0125-preview', num_queries=25)
# Out:
# Info: 1.99% of the rows in this dataset are duplicates.
# 5,3.5,1.3,0.3,Iris-setosa
# 5.9,3.2,4.8,1.8,Iris-versicolor
# 6.9,3.2,5.7,2.3,Iris-virginica
# 5.7,3.8,1.7,0.3,Iris-setosa
# 6.7,3.1,5.6,2.4,Iris-virginica
# 5.5,2.5,4.9,1.3,Iris-versicolor
# 6.3,2.8,5.1,1.5,Iris-virginica
# 6.4,3.2,4.5,1.5,Iris-versicolor
# 7.3,2.9,6.3,1.8,Iris-virginica
# 6,2.2,5,1.5,Iris-virginica
# 6.1,2.6,5.6,1.4,Iris-virginica
# 4.8,3.4,1.9,0.2,Iris-setosa
# 6.3,2.7,4.9,1.8,Iris-virginica
# 6.8,3.2,5.9,2.3,Iris-virginica
# 6.3,3.3,4.7,1.6,Iris-versicolor
# 5.9,3,4.2,1.5,Iris-versicolor
# 4.4,3.2,1.3,0.2,Iris-setosa
# 6.3,2.9,5.6,1.8,Iris-virginica
# 5.2,4.1,1.5,0.1,Iris-setosa
# 6.7,3,5,1.7,Iris-versicolor
# 5.7,4.4,1.5,0.4,Iris-setosa
# 5,3.5,1.6,0.6,Iris-setosa
# 7.1,3,5.9,2.1,Iris-virginica
# 6,2.7,5.1,6,1.6,Iris-versicolor
# 5.5,2.6,4.4,1.2,Iris-versicolor
# Row Completion Test: 22/25 exact matches.

# %%
display(HTML('<br>'.join([tabmemcheck.utils.levenshtein_html(row, response) for row, response in zip(rows, responses)])))
# Out:
# <span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">0</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">I</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">-</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">t</span><span style="background-color:#7CFC00">o</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">a</span><br><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">.</span><span style="background-color:#EE4B2B">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#EE4B2B">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#EE4B2B">2</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">4</span><span style="background-color:#EE4B2B">.</span><span style="background-color:#EE4B2B">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">1</span><span style="background-color:#7CFC00">.</span><span style="background-color:#EE4B2B">8</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">I</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">-</span><span style="background-color:#7CFC00">v</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">c</span><span style="background-color:#7CFC00">o</span><span style="background-color:#7CFC00">l</span><span style="background-color:#7CFC00">o</span><span style="background-color:#7CFC00">r</span><br><span style="background-color:#7CFC00">6</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">9</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">5</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">7</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">2</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00">3</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00">I</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">-</span><span style="background-color:#7CFC00">v</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">g</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">c</sp ...

# %% [markdown]
# ## The feature completion test asks the LLM to complete the value of a specific feature in a csv file
# #### It provides strong evidence of memorization of the Kaggle Titanic datast

# %%
feature_values, responses = tabmemcheck.feature_completion_test('/home/sebastian/Downloads/titanic-train.csv', 'gpt-3.5-turbo-0125', feature_name='Name', num_queries=25)
# Out:
# Feature Completion Test ("Name"): 25/25 exact matches.

# %%
display(HTML('<br>'.join([tabmemcheck.utils.levenshtein_html(feature, response) for feature, response in zip(feature_values, responses)])))
# Out:
# <span style="background-color:#7CFC00">L</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">t</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">J</span><span style="background-color:#7CFC00">a</span><span style="background-color:#7CFC00">m</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">s</span><br><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">a</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">w</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">l</span><span style="background-color:#7CFC00">l</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">(</span><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">a</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">o</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">O</span><span style="background-color:#7CFC00">g</span><span style="background-color:#7CFC00">d</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">)</span><br><span style="background-color:#7CFC00">F</span><span style="background-color:#7CFC00">u</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">k</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">s</span><span style="background-color:#7CFC00">.</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">A</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">C</span><span style="background-color:#7CFC00">l</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">m</span><span style="background-color:#7CFC00">m</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">r</span><br><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">c</span><span style="background-color:#7CFC00">G</span><span style="background-color:#7CFC00">o</span><span style="background-color:#7CFC00">v</span><span style="background-color:#7CFC00">e</span><span style="background-color:#7CFC00">r</span><span style="background-color:#7CFC00">n</span><span style="background-color:#7CFC00">,</span><span style="background-color:#7CFC00"> </span><span style="background-color:#7CFC00">M</span><span style="background-color:#7CFC00">i</span><span style="background-color:#7CFC00">s ...

# %% [markdown]
# ## The first token test asks the LLM to complete the value of the first token in the next row of a csv file

# %% [markdown]
# #### It provides no evidence of memorization of the Adult Income dataset

# %%
tabmemcheck.first_token_test('adult-train.csv', 'gpt-3.5-turbo-0125', num_queries=100)
# Out:
# First Token Test: 37/100 exact matches.
# First Token Test Baseline (Matches of most common first token): 50/100.

# %% [markdown]
# ## You can see all prompts that are being send to the model, and the raw responses

# %%
tabmemcheck.config.print_prompts = True
tabmemcheck.feature_completion_test('/home/sebastian/Downloads/titanic-train.csv', 'gpt-3.5-turbo-0125', feature_name='Name', num_queries=1)
# Out:
# System: You are a helpful autocomplete bot for tabular datasets. You will be prompted with a portion of a sample from a machine learning dataset. Your task is to complete the observation from the dataset. The observations are presented to you in the format "Feature Name = Feature Value".
# User: PassengerId = 757, Survived = 0, Pclass = 3, Sex = male, Age = 28.0, SibSp = 0, Parch = 0, Ticket = 350042, Fare = 7.7958, Cabin = nan, Embarked = S
# Assistant: Name = Carlsson, Mr. August Sigfrid
# User: PassengerId = 19, Survived = 0, Pclass = 3, Sex = female, Age = 31.0, SibSp = 1, Parch = 0, Ticket = 345763, Fare = 18.0, Cabin = nan, Embarked = S
# Assistant: Name = Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# User: PassengerId = 730, Survived = 0, Pclass = 3, Sex = female, Age = 25.0, SibSp = 1, Parch = 0, Ticket = STON/O2. 3101271, Fare = 7.925, Cabin = nan, Embarked = S
# Assistant: Name = Ilmakangas, Miss. Pieta Sofia
# User: PassengerId = 367, Survived = 1, Pclass = 1, Sex = female, Age = 60.0, SibSp = 1, Parch = 0, Ticket = 110813, Fare = 75.25, Cabin = D37, Embarked = C
# Assistant: Name = Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# User: PassengerId = 98, Survived = 1, Pclass = 1, Sex = male, Age = 23.0, SibSp = 0, Parch = 1, Ticket = PC 17759, Fare = 63.3583, Cabin = D10 D12, Embarked = C
# Assistant: Name = Greenfield, Mr. William Bertram
# User: PassengerId = 209, Survived = 1, Pclass = 3, Sex = female, Age = 16.0, SibSp = 0, Parch = 0, Ticket = 367231, Fare = 7.75, Cabin = nan, Embarked = Q
# Response: Name = Carr, Miss. Helen "Ellen"
# Feature Completion Test ("Name"): 1/1 exact matches.
# (['Carr, Miss. Helen "Ellen"'], ['Carr, Miss. Helen "Ellen"'])
