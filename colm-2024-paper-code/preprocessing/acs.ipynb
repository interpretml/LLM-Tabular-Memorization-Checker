# %% [markdown]
# # 2022 American Community Survey (ACS)
# ### Here we create the ACS Income and ACS Travel datasets
# #### https://en.wikipedia.org/wiki/American_Community_Survey
# #### See also the data dictionary: https://www2.census.gov/programs-surveys/acs/tech_docs/pums/data_dict/PUMS_Data_Dictionary_2022.pdf

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm

import folktables
from folktables import ACSDataSource

# %%
data_source = ACSDataSource(survey_year='2022', horizon='1-Year', survey='person')
ca_data = data_source.get_data(states=["CA"], download=True)

# %%
# the variable 'RELP' is not available in the 2022 1-Year ACS. so we remove it
ACSIncomeNew = folktables.BasicProblem(
    features=[
        'AGEP',
        'COW',
        'SCHL',
        'MAR',
        'OCCP',
        'POBP',
 #       'RELP',
        'WKHP',
        'SEX',
        'RAC1P',
    ],
    target='PINCP',
    target_transform=lambda x: x > 50000,    
    group='RAC1P',
    preprocess=folktables.adult_filter,
    postprocess=lambda x: np.nan_to_num(x, -1),
)
X_data, y_data, _ = ACSIncomeNew.df_to_pandas(ca_data)

# %%
feature_names = ["Age",
                 "Class of worker",
                 "Educational attainment",
                 "Marital status",
                 "Occupation",
                 "Place of birth",
                 "Usual hours worked per week past 12 months",
                 "Sex",
                 "Recoded race"]

# %%
# COW
with open('PUMS_Data_Dictionary_2022/COW.txt', 'r') as file:
    filedata = file.read()
COW_dict = {}
for x in filedata.split('\n'):
    COW_dict[int(x[:1])] = x[2:]

# SCHL
with open('PUMS_Data_Dictionary_2022/SCHL.txt', 'r') as file:
    filedata = file.read()
SCHL_dict = {}    
for x in filedata.split('\n'):
    SCHL_dict[int(x[:2])] = x[3:]

# MAR
with open('PUMS_Data_Dictionary_2022/MAR.txt', 'r') as file:
    filedata = file.read()
MAR_dict = {}
for x in filedata.split('\n'):
    MAR_dict[int(x[:1])] = x[2:]

# OCCP 
with open('PUMS_Data_Dictionary_2022/OCCP.txt', 'r') as file:
    filedata = file.read()
OCCP_dict = {}
for x in filedata.split('\n'):
    OCCP_dict[int(x[:4])] = x[10:]
OCCP_dict[9920] = "Unemployed, With No Work Experience In The Last 5 Years Or Earlier Or Never Worked"

# POBP
with open('PUMS_Data_Dictionary_2022/POBP.txt', 'r') as file:
    filedata = file.read()
POBP_dict = {}
for x in filedata.split('\n'):
    POBP_dict[int(x[:3])] = x[5:] 

# SEX
SEX_dict = {1: "Male", 2: "Female"}

# RAC1P
with open('PUMS_Data_Dictionary_2022/RAC1P.txt', 'r') as file:
    filedata = file.read()
RAC1P_dict = {}
for x in filedata.split('\n'):
    RAC1P_dict[int(x[:1])] = x[3:]

# %%
X_data_llm = X_data.copy()

X_data_llm['AGEP'] = X_data_llm['AGEP'].astype(int)
X_data_llm['WKHP'] = X_data_llm['WKHP'].astype(int)
# replace entries in column COW with the entries in COW_dict
X_data_llm['COW'] = X_data_llm['COW'].map(COW_dict)
X_data_llm['SCHL'] = X_data_llm['SCHL'].map(SCHL_dict)
X_data_llm['MAR'] = X_data_llm['MAR'].map(MAR_dict)
X_data_llm['OCCP'] = X_data_llm['OCCP'].map(OCCP_dict)
X_data_llm['POBP'] = X_data_llm['POBP'].map(POBP_dict)
X_data_llm['SEX'] = X_data_llm['SEX'].map(SEX_dict)
X_data_llm['RAC1P'] = X_data_llm['RAC1P'].map(RAC1P_dict)

# %%
#y_data_llm = y_data['PINCP'].map({True: "Makes more than $50,000 per year.", False: "Makes less than $50,000 per year."})
y_data_llm = y_data['PINCP'].map({True: "More than $50,000 per year.", False: "Less than $50,000 per year."})

# %%
X_data_llm.head()
# Out:
#    AGEP                                                COW  \
# 0    26  Employee of a private for-profit company or bu...
# 1    38                        Federal government employee
# 2    23                        Federal government employee
# 3    20  Employee of a private for-profit company or bu...
# 4    20                        Federal government employee
#
#                                            SCHL  \
# 0  1 or more years of college credit, no degree
# 1                   Regular high school diploma
# 2                   Regular high school diploma
# 3  1 or more years of college credit, no degree
# 4                   Regular high school diploma
#
#                                    MAR  \
# 0  Never married or under 15 years old
# 1                             Divorced
# 2  Never married or under 15 years old
# 3  Never married or under 15 years old
# 4  Never married or under 15 years old
#
#                                                 OCCP          POBP  WKHP  \
# 0                              Food Service Managers        Mexico    30
# 1                                      Photographers    Arizona/AZ    40
# 2  Military Enlisted Tactical Operations And Air/...    Montana/MT    40
# 3                      Fast Food And Counter Workers     Nevada/NV    20
# 4                       Military, Rank Not Specified  Tennessee/TN    50
#
#       SEX                  RAC1P
# 0  Female  Some Other Race alone
# 1  Female            White alone
# 2    Male      Two or More Races
# 3    Male  Some Other Race alone
# 4  Female      Two or More Races

# %% [markdown]
# ### save the llm data to csv

# %%
df = pd.concat([X_data_llm, y_data_llm], axis=1)
# set column names to feature names
df.columns = feature_names + ['Target']
df.to_csv('../csv/acs-income-2022.csv', index=False)
df.head()

# %% [markdown]
# # ACSTravelTime

# %%
# from https://github.com/socialfoundations/folktables/blob/731b8d1470d36bbc1821e1953ba1308303eef95f/folktables/acs.py#L213
def travel_time_filter(data):
    """
    Filters for the employment prediction task
    """
    df = data
    df = df[df['AGEP'] > 16]
    df = df[df['PWGTP'] >= 1]
    df = df[df['ESR'] == 1]
    return df

ACSTravelTimeNew = folktables.BasicProblem(
    features=[
        'AGEP',
        'SCHL',
        'MAR',
        'SEX',
        'DIS',
        'ESP',
        'MIG',
#        'RELP',
        'RAC1P',
        'PUMA',
        'ST',
        'CIT',
        'OCCP',
 #       'JWTR',
       'POWPUMA',
       'POWSP'              # needed for pre-processing POWPUMA
 #       'POVPIP',
    ],
    target="JWMNP",
    target_transform=lambda x: x > 20,
    group='RAC1P',
    preprocess=travel_time_filter,
    postprocess=lambda x: np.nan_to_num(x, -1),
)
X_data, y_data, _ = ACSTravelTimeNew.df_to_pandas(ca_data)

# %%
X_data
# Out:
#         AGEP  SCHL  MAR  SEX  DIS  ESP  MIG  RAC1P     PUMA   ST  CIT    OCCP  \
# 0       26.0  19.0  5.0  2.0  1.0  0.0  1.0    8.0   8303.0  6.0  4.0   310.0
# 1       47.0  14.0  3.0  2.0  2.0  0.0  3.0    1.0   3712.0  6.0  1.0  8990.0
# 2       18.0  16.0  5.0  2.0  2.0  0.0  3.0    1.0  11301.0  6.0  1.0  3960.0
# 3       21.0  16.0  5.0  1.0  2.0  0.0  1.0    2.0    116.0  6.0  1.0  4720.0
# 4       23.0  20.0  5.0  1.0  2.0  0.0  1.0    1.0   8702.0  6.0  1.0  5850.0
# ...      ...   ...  ...  ...  ...  ...  ...    ...      ...  ...  ...     ...
# 177719  32.0  22.0  5.0  2.0  1.0  0.0  1.0    6.0   5918.0  6.0  1.0  2004.0
# 177720  33.0  19.0  1.0  2.0  2.0  0.0  1.0    9.0   2908.0  6.0  1.0  2016.0
# 177721  53.0  16.0  1.0  2.0  2.0  0.0  1.0    8.0   3752.0  6.0  5.0  5000.0
# 177722  51.0  11.0  1.0  1.0  2.0  0.0  1.0    8.0   3752.0  6.0  5.0  9620.0
# 177723  20.0  16.0  5.0  2.0  2.0  0.0  1.0    8.0   3752.0  6.0  5.0  4055.0
#
#         POWPUMA  POWSP
# 0        8300.0    6.0
# 1        7300.0    6.0
# 2        5900.0    6.0
# 3         100.0    6.0
# 4        8700.0    6.0
# ...         ...    ...
# 177719   5900.0    6.0
# 177720   2900.0    6.0
# 177721   3700.0    6.0
# 177722   3700.0    6.0
# 177723   3700.0    6.0
#
# [177724 rows x 14 columns]

# %%
# train a gradient boosted tree to ballpark the amount of signal in the data
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42)

model = xgb.XGBClassifier(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7010268673512449

# %%
# ESP
with open('PUMS_Data_Dictionary_2022/ESP.txt', 'r') as file:
    filedata = file.read()
ESP_dict = {}
for x in filedata.split('\n'):
    ESP_dict[int(x[:1].strip())] = x[6:]
    
# DIS
DIS_dict = {1: "With a disability", 2: "Without a disability"}

# PUMA
with open('PUMS_Data_Dictionary_2022/PUMA.txt', 'r') as file:
    filedata = file.read()
PUMA_dict = {}
for x in filedata.split('\n'):
    st = int(x[:2])
    puma = int(x[3:8])
    v = x[9:].strip()
    if st in PUMA_dict:
        PUMA_dict[st][puma] = v
    else:
        PUMA_dict[st] = {puma: v}

# ST
with open('PUMS_Data_Dictionary_2022/ST.txt', 'r') as file:
    filedata = file.read()
ST_dict = {}
for x in filedata.split('\n'):
    ST_dict[int(x[:2].strip())] = x[3:].strip()[1:]

# CIT        
CIT_dict = {1: "Born in the United States", 2: "Born in Puerto Rico, Guam, the U.S. Virgin Islands, or Northern Marianas", 3: "Born abroad of U.S. citizen parent or parents", 4: "U.S. citizen by naturalization", 5: "Not a U.S. citizen"}

# MIG
MIG_dict = {0: ".N/A (less than 1 year old)", 1: "Yes, same house (nonmovers)", 2: "No, outside US and Puerto Rico", 3: "No, different house in US or Puerto Rico"}

# %%
X_data_llm = X_data.copy()

X_data_llm['AGEP'] = X_data_llm['AGEP'].astype(int)
X_data_llm['SCHL'] = X_data_llm['SCHL'].map(SCHL_dict)
X_data_llm['MAR'] = X_data_llm['MAR'].map(MAR_dict)
X_data_llm['SEX'] = X_data_llm['SEX'].map(SEX_dict)
X_data_llm['ESP'] = X_data_llm['ESP'].map(ESP_dict)
X_data_llm['DIS'] = X_data_llm['DIS'].map(DIS_dict)

# PUMA
values = []
for idx in range(X_data_llm.shape[0]):
    st = X_data_llm.iloc[idx]['ST']
    puma = X_data_llm.iloc[idx]['PUMA']
    values.append(PUMA_dict[int(st)][int(puma)])
X_data_llm['PUMA'] = values

# POWPUMA
# powpuma in the census data is less specific and does not contain the last digit code. we extract the larger area string from the more specific subregions
from os.path import commonprefix
values = []
for idx in range(X_data_llm.shape[0]):
    st = X_data_llm.iloc[idx]['POWSP']
    puma = X_data_llm.iloc[idx]['POWPUMA']
    if not int(st) in PUMA_dict:
        values.append("N/A")
        continue
    sub_values = []
    for i in range(100):
        if (int(puma)+i) in PUMA_dict[int(st)]:
            sub_values.append(PUMA_dict[int(st)][int(puma)+i])
    values.append(commonprefix(sub_values).strip().strip('('))
X_data_llm['POWPUMA'] = values

# drop powsp
X_data_llm = X_data_llm.drop(columns=['POWSP'])

X_data_llm['MIG'] = X_data_llm['MIG'].map(MIG_dict)
X_data_llm['CIT'] = X_data_llm['CIT'].map(CIT_dict)
X_data_llm['ST'] = X_data_llm['ST'].map(ST_dict)
X_data_llm['RAC1P'] = X_data_llm['RAC1P'].map(RAC1P_dict)
X_data_llm['OCCP'] = X_data_llm['OCCP'].map(OCCP_dict)

# %%
X_data_llm.head()
# Out:
#    AGEP                                          SCHL  \
# 0    26  1 or more years of college credit, no degree
# 1    47                                      Grade 11
# 2    18                   Regular high school diploma
# 3    21                   Regular high school diploma
# 4    23                            Associate's degree
#
#                                    MAR     SEX                   DIS  \
# 0  Never married or under 15 years old  Female     With a disability
# 1                             Divorced  Female  Without a disability
# 2  Never married or under 15 years old  Female  Without a disability
# 3  Never married or under 15 years old    Male  Without a disability
# 4  Never married or under 15 years old    Male  Without a disability
#
#                                                  ESP  \
# 0  N/A (not own child of householder, and not chi...
# 1  N/A (not own child of householder, and not chi...
# 2  N/A (not own child of householder, and not chi...
# 3  N/A (not own child of householder, and not chi...
# 4  N/A (not own child of householder, and not chi...
#
#                                         MIG                            RAC1P  \
# 0               Yes, same house (nonmovers)            Some Other Race alone
# 1  No, different house in US or Puerto Rico                      White alone
# 2  No, different house in US or Puerto Rico                      White alone
# 3               Yes, same house (nonmovers)  Black or African American alone
# 4               Yes, same house (nonmovers)                      White alone
#
#                                                 PUMA             ST  \
# 0           Santa Barbara County--South Coast Region  California/CA
# 1     Los Angeles County (East Central)--Pomona City  California/CA
# 2  Yolo County (North)--Woodland & Winters Cities...  California/CA
# 3      Alameda County (Central)--Hayward City (East)  California/CA
# 4  Santa Cruz County (South & Coastal)--Santa Cru...  California/CA
#
#                               CIT  \
# 0  U.S. citizen by naturalization
# 1       Born in the United States
# 2       Born in the United States
# 3       Born in the United States
# 4       Born in the United States
#
#                                                 OCCP               POWPUMA
# 0                              Food Service Managers  Santa Barbara County
# 1  Miscellaneous Production Workers, Including Eq...     San Diego County
# 2                   Other Protective Service Workers        Orange County
# 3                                           Cashiers       Alameda County
# 4  Mail Clerks And Mail Machine Operators, Except...    Santa Cruz County

# %%
X_data_llm.columns = ["Age", "Educational attainment", "Marital status", "Sex", "Disability", "Employment status of parents", "Lived here 1 year ago", "Recorded race", "Living Area", "State", "Citizenship", "Occupation", "Place of Work Area"]

# %%
X_data_llm
# Out:
#         Age                        Educational attainment  \
# 0        26  1 or more years of college credit, no degree
# 1        47                                      Grade 11
# 2        18                   Regular high school diploma
# 3        21                   Regular high school diploma
# 4        23                            Associate's degree
# ...     ...                                           ...
# 177719   32                               Master's degree
# 177720   33  1 or more years of college credit, no degree
# 177721   53                   Regular high school diploma
# 177722   51                                       Grade 8
# 177723   20                   Regular high school diploma
#
#                              Marital status     Sex            Disability  \
# 0       Never married or under 15 years old  Female     With a disability
# 1                                  Divorced  Female  Without a disability
# 2       Never married or under 15 years old  Female  Without a disability
# 3       Never married or under 15 years old    Male  Without a disability
# 4       Never married or under 15 years old    Male  Without a disability
# ...                                     ...     ...                   ...
# 177719  Never married or under 15 years old  Female     With a disability
# 177720                              Married  Female  Without a disability
# 177721                              Married  Female  Without a disability
# 177722                              Married    Male  Without a disability
# 177723  Never married or under 15 years old  Female  Without a disability
#
#                              Employment status of parents  \
# 0       N/A (not own child of householder, and not chi...
# 1       N/A (not own child of householder, and not chi...
# 2       N/A (not own child of householder, and not chi...
# 3       N/A (not own child of householder, and not chi...
# 4       N/A (not own child of householder, and not chi...
# ...                                                   ...
# 177719  N/A (not own child of householder, and not chi...
# 177720  N/A (not own child of householder, and not chi...
# 177721  N/A (not own child of householder, and not chi...
# 177722  N/A (not own child of householder, and not chi...
# 177723  N/A (not own child of householder, and not chi...
#
#                            Lived here 1 year ago  \
# 0                    Yes, same house (nonmovers)
# 1       No, different house in US or Puerto Rico
# 2       No, different house in US or Puerto Rico
# 3                    Yes, same house (nonmovers)
# 4                    Yes, same house (nonmovers)
# ...                                          ...
# 177719               Yes, same house (nonmovers)
# 177720               Yes, same house (nonmovers)
# 177721               Yes, same house (nonmovers)
# 177722               Yes, same house (nonmovers)
# 177723               Yes, same house (nonmovers)
#
#                           Recorded race  \
# 0                 Some Other Race alone
# 1                           White alone
# 2                           White alone
# 3       Black or African American alone
# 4                           White alone
# ...                                 ...
# 177719                      Asian alone
# 177720                Two or More Races
# 177721            Some Other Race alone
# 177722            Some Other Race alone
# 177723            Some Other Race alone
#
#                                               Living Area          State  \
# 0                Santa Barbara County--South Coast Region  California/CA
# 1          Los Angeles County (East Central)--Pomona City  California/CA
# 2       Yolo County (North)--Woodland & Winters Cities...  California/CA
# 3           Alameda County (Central)--Hayward City (East)  California/CA
# 4       Santa Cruz County (South & Coastal)--Santa Cru...  California/CA
# ...                                                   ...            ...
# 177719  Orange County (Central)--Costa Mesa & Fountain...  California/CA
# 177720  Kern County (Central)--Bakersfield City (South...  California/CA
# 177721  Los Angeles County (South)--South Gate & Lynwo...  California/CA
# 177722  Los Angeles County (South)--South Gate & Lynwo...  California/CA
# 177723  Los Angeles County (South)--South Gate & Lynwo...  California/CA
#
#                            Citizenship  \
# 0       U.S. citizen by naturalization
# 1            Born in the United States
# 2            Born in the United States
# 3            Born in the United States
# 4            Born in the United States
# ...                                ...
# 177719       Born in the United States
# 177720       Born in the United States
# 177721              Not a U.S. citizen
# 177722              Not a U.S. citizen
# 177723              Not a U.S. citizen
#
#                                                Occupation  \
# 0                                   Food Service Managers
# 1       Miscellaneous Production Workers, Including Eq...
# 2                        Other Protective Service Workers
# 3                                                Cashiers
# 4       Mail Clerks And Mail Machine Operators, Except...
# ...                                                   ...
# 177719                           Mental Health Counselors
# 177720                Social And Human Service Assistants
# 177721  First-Line Supervisors Of Office And Administr...
# 177722  Laborers And Freight, Stock, And Material Move...
# 177723                      Fast Food And Counter Workers
#
#           Place of Work Area
# 0       Santa Barbara County
# 1          San Diego County
# 2             Orange County
# 3            Alameda County
# 4         Santa Cruz County
# ...                      ...
# 177719        Orange County
# 177720          Kern County
# 177721    Los Angeles County
# 177722    Los Angeles County
# 177723    Los Angeles County
#
# [177724 rows x 13 columns]

# %%
y_data.columns = ["Travel Time to Work"]

# re-encode target
y_data = y_data['Travel Time to Work'].map({True: "More than 20 minutes", False: "Less than 20 minutes"})

# %%
df = pd.concat([X_data_llm, y_data], axis=1)
# set column names to feature names

df.to_csv('../acs-travel-2022.csv', index=False)
df.head()
# Out:
#    Age                        Educational attainment  \
# 0   26  1 or more years of college credit, no degree
# 1   47                                      Grade 11
# 2   18                   Regular high school diploma
# 3   21                   Regular high school diploma
# 4   23                            Associate's degree
#
#                         Marital status     Sex            Disability  \
# 0  Never married or under 15 years old  Female     With a disability
# 1                             Divorced  Female  Without a disability
# 2  Never married or under 15 years old  Female  Without a disability
# 3  Never married or under 15 years old    Male  Without a disability
# 4  Never married or under 15 years old    Male  Without a disability
#
#                         Employment status of parents  \
# 0  N/A (not own child of householder, and not chi...
# 1  N/A (not own child of householder, and not chi...
# 2  N/A (not own child of householder, and not chi...
# 3  N/A (not own child of householder, and not chi...
# 4  N/A (not own child of householder, and not chi...
#
#                       Lived here 1 year ago                    Recorded race  \
# 0               Yes, same house (nonmovers)            Some Other Race alone
# 1  No, different house in US or Puerto Rico                      White alone
# 2  No, different house in US or Puerto Rico                      White alone
# 3               Yes, same house (nonmovers)  Black or African American alone
# 4               Yes, same house (nonmovers)                      White alone
#
#                                          Living Area          State  \
# 0           Santa Barbara County--South Coast Region  California/CA
# 1     Los Angeles County (East Central)--Pomona City  California/CA
# 2  Yolo County (North)--Woodland & Winters Cities...  California/CA
# 3      Alameda County (Central)--Hayward City (East)  California/CA
# 4  Santa Cruz County (South & Coastal)--Santa Cru...  California/CA
#
#                       Citizenship  \
# 0  U.S. citizen by naturalization
# 1       Born in the United States
# 2       Born in the United States
# 3       Born in the United States
# 4       Born in the United States
#
#                                           Occupation    Place of Work Area  \
# 0                              Food Service Managers  Santa Barbara County
# 1  Miscellaneous Production Workers, Including Eq...     San Diego County
# 2                   Other Protective Service Workers        Orange County
# 3                                           Cashiers       Alameda County
# 4  Mail Clerks And Mail Machine Operators, Except...    Santa Cruz County
#
#     Travel Time to Work
# 0  Less than 20 minutes
# 1  More than 20 minutes
# 2  Less than 20 minutes
# 3  Less than 20 minutes
# 4  Less than 20 minutes
